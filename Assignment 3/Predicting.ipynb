# %%
import threading

# Helper thread to avoid the Spark StreamingContext from blocking Jupyter
        
class StreamingThread(threading.Thread):
    def __init__(self, ssc):
        super().__init__()
        self.ssc = ssc
    def run(self):
        self.ssc.start()
        self.ssc.awaitTermination()
    def stop(self):
        print('----- Stopping... this may take a few seconds -----')
        self.ssc.stop(stopSparkContext=False, stopGraceFully=True)

# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://LAPTOP-DEAJH2JG:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import random
from pyspark.streaming import StreamingContext
from pyspark.sql import Row
from pyspark.sql.functions import udf, struct, array, col, lit
from pyspark.sql.types import StringType
from pyspark.ml.pipeline import PipelineModel

# %%
globals()['models_loaded'] = False
globals()['my_model'] = None

def process(time, rdd):
    if rdd.isEmpty():
        return
    
    print("========= %s =========" % str(time))
    
    # Convert to data frame
    df = spark.read.json(rdd)
    #df.select(["title", "frontpage"]).show()
    
    # Load in the model if not yet loaded:
    if not globals()['models_loaded']:
        # load in your models here
        globals()['my_model'] = PipelineModel.load("gb_Model")
        globals()['models_loaded'] = True
        
    # And then predict using the loaded model (uncomment below):
    
    df_result = globals()['my_model'].transform(df)
    df_result.select(["title", "frontpage", "prediction"]).show()

# %%
ssc = StreamingContext(sc, 10)

# %%
lines = ssc.socketTextStream("seppe.net", 7778)
lines.foreachRDD(process)

# %%
ssc_t = StreamingThread(ssc)
ssc_t.start()
# Out:
# ========= 2024-04-30 14:28:50 =========
# +--------------------+---------+
# |               title|frontpage|
# +--------------------+---------+
# |What makes OpenBS...|    false|
# +--------------------+---------+
#
# +--------------------+---------+----------+
# |               title|frontpage|prediction|
# +--------------------+---------+----------+
# |What makes OpenBS...|    false|       0.0|
# +--------------------+---------+----------+
#
# ========= 2024-04-30 14:29:00 =========
# +--------------------+---------+
# |               title|frontpage|
# +--------------------+---------+
# |What consumers sh...|    false|
# |First Time Ever L...|    false|
# +--------------------+---------+
#
# +--------------------+---------+----------+
# |               title|frontpage|prediction|
# +--------------------+---------+----------+
# |What consumers sh...|    false|       1.0|
# |First Time Ever L...|    false|       0.0|
# +--------------------+---------+----------+
#
# ========= 2024-04-30 14:29:10 =========
# +--------------------+---------+
# |               title|frontpage|
# +--------------------+---------+
# |Show HN: A cross-...|    false|
# |Electromigration ...|     true|
# |Saudis Scale Back...|     true|
# |Chaos with a Spre...|    false|
# |Unconventional Ag...|    false|
# +--------------------+---------+
#
# +--------------------+---------+----------+
# |               title|frontpage|prediction|
# +--------------------+---------+----------+
# |Show HN: A cross-...|    false|       1.0|
# |Electromigration ...|     true|       1.0|
# |Saudis Scale Back...|     true|       1.0|
# |Chaos with a Spre...|    false|       0.0|
# |Unconventional Ag...|    false|       0.0|
# +--------------------+---------+----------+
#
# ========= 2024-04-30 14:29:20 =========
# +--------------------+---------+
# |               title|frontpage|
# +--------------------+---------+
# |Traveling at the ...|    false|
# | Worldwide Telescope|    false|
# |Judge0 Sandbox Es...|    false|
# +--------------------+---------+
#
# +--------------------+---------+----------+
# |               title|frontpage|prediction|
# +--------------------+---------+----------+
# |Traveling at the ...|    false|       0.0|
# | Worldwide Telescope|    false|       0.0|
# |Judge0 Sandbox Es...|    false|       0.0|
# +--------------------+---------+----------+
#
# ========= 2024-04-30 14:29:30 =========
# +--------------------+---------+
# |               title|frontpage|
# +--------------------+---------+
# |Using SQLite as a...|    false|
# |The web is not dying|    false|
# |DoltgreSQL – Data...|    false|
# |RISC-V support in...|     true|
# +--------------------+---------+
#
# +--------------------+---------+----------+
# |               title|frontpage|prediction|
# +--------------------+---------+----------+
# |Using SQLite as a...|    false|       0.0|
# |The web is not dying|    false|       0.0|
# |DoltgreSQL – Data...|    false|       0.0|
# |RISC-V support in...|     true|       1.0|
# +--------------------+---------+----------+
#
# ========= 2024-04-30 14:29:40 =========
# +--------------------+---------+
# |               title|frontpage|
# +--------------------+---------+
# |The volunteers pu...|    false|
# |A Peek Inside the...|    false|
# |Mactop Released (...|    false|
# |Why SQLite Uses B...|     true|
# +--------------------+---------+
#
# +--------------------+---------+----------+
# |               title|frontpage|prediction|
# +--------------------+---------+----------+
# |The volunteers pu...|    false|       0.0|
# |A Peek Inside the...|    false|       0.0|
# |Mactop Released (...|    false|       0.0|
# |Why SQLite Uses B...|     true|       1.0|
# +--------------------+---------+----------+
#
# ========= 2024-04-30 14:29:50 =========
# +--------------------+---------+
# |               title|frontpage|
# +--------------------+---------+
# |Implementing Your...|    false|
# |Codapi – Interact...|     true|
# +--------------------+---------+
#
# +--------------------+---------+----------+
# |               title|frontpage|prediction|
# +--------------------+---------+----------+
# |Implementing Your...|    false|       0.0|
# |Codapi – Interact...|     true|       1.0|
# +--------------------+---------+----------+
#
# ========= 2024-04-30 14:30:00 =========
# +--------------------+---------+
# |               title|frontpage|
# +--------------------+---------+
# |Save the Web by B...|     true|
# |The Stabilizer Pr...|    false|
# |Do the GDP and Do...|    false|
# +--------------------+---------+
#
# +--------------------+---------+----------+
# |               title|frontpage|prediction|
# +--------------------+---------+----------+
# |Save the Web by B...|     true|       1.0|
# |The Stabilizer Pr...|    false|       0.0|
# |Do the GDP and Do...|    false|       0.0|
# +--------------------+---------+----------+
#
# ========= 2024-04-30 14:30:10 =========
# +--------------------+---------+
# |               title|frontpage|
# +--------------------+---------+
# |The new class war...|     true|
# |BRICS Conducts $2...|    false|
# |Legent: Open Plat...|    false|
# +--------------------+---------+
#
# +--------------------+---------+----------+
# |               title|frontpage|prediction|
# +--------------------+---------+----------+
# |The new class war...|     true|       1.0|
# |BRICS Conducts $2...|    false|       0.0|
# |Legent: Open Plat...|    false|       0.0|
# +--------------------+---------+----------+
#
# ========= 2024-04-30 14:30:20 =========
# +--------------------+---------+
# |               title|frontpage|
# +--------------------+---------+
# |5k word essay on ...|    false|
# |A few facts about...|     true|
# |The Two Clock Pro...|    false|
# +--------------------+---------+
#
# +--------------------+---------+----------+
# |               title|frontpage|prediction|
# +--------------------+---------+----------+
# |5k word essay on ...|    false|       0.0|
# |A few facts about...|     true|       1.0|
# |The Two Clock Pro...|    false|       0.0|
# +--------------------+---------+----------+
#
# ========= 2024-04-30 14:30:30 =========
# +--------------------+---------+
# |               title|frontpage|
# +--------------------+---------+
# |How We Tracked Do...|    false|
# |Report suggests S...|    false|
# |Pretraining Witho...|    false|
# +--------------------+---------+
#
# +--------------------+---------+----------+
# |               title|frontpage|prediction|
# +--------------------+---------+----------+
# |How We Tracked Do...|    false|       0.0|
# |Report suggests S...|    false|       0.0|
# |Pretraining Witho...|    false|       0.0|
# +--------------------+---------+----------+
#
# ========= 2024-04-30 14:30:40 =========
# +--------------------+---------+
# |               title|frontpage|
# +--------------------+---------+
# |CDC: Technical Hi...|    false|
# |Doclite: PHP NoSQ...|    false|
# |I learned how Tou...|    false|
# +--------------------+---------+
#
# +--------------------+---------+----------+
# |               title|frontpage|prediction|
# +--------------------+---------+----------+
# |CDC: Technical Hi...|    false|       0.0|
# |Doclite: PHP NoSQ...|    false|       0.0|
# |I learned how Tou...|    false|       0.0|
# +--------------------+---------+----------+
#
# ========= 2024-04-30 14:30:50 =========
# +--------------------+---------+
# |               title|frontpage|
# +--------------------+---------+
# |How to train diff...|    false|
# |Surreal claims, l...|     true|
# |Friends from the ...|    false|
# +--------------------+---------+
#
# +--------------------+---------+----------+
# |               title|frontpage|prediction|
# +--------------------+---------+----------+
# |How to train diff...|    false|       0.0|
# |Surreal claims, l...|     true|       1.0|
# |Friends from the ...|    false|       0.0|
# +--------------------+---------+----------+
#
# ========= 2024-04-30 14:31:00 =========

# %%
ssc_t.stop()
# Out:
# ----- Stopping... this may take a few seconds -----
# +--------------------+---------+
# |               title|frontpage|
# +--------------------+---------+
# |Show HN: Thru – C...|    false|
# |American Airlines...|    false|
# |Amateur birder in...|     true|
# +--------------------+---------+
#
# +--------------------+---------+----------+
# |               title|frontpage|prediction|
# +--------------------+---------+----------+
# |Show HN: Thru – C...|    false|       0.0|
# |American Airlines...|    false|       0.0|
# |Amateur birder in...|     true|       1.0|
# +--------------------+---------+----------+
#
# ========= 2024-04-30 14:31:10 =========
# +--------------------+---------+
# |               title|frontpage|
# +--------------------+---------+
# |Vaping linked wit...|     true|
# +--------------------+---------+
#
# +--------------------+---------+----------+
# |               title|frontpage|prediction|
# +--------------------+---------+----------+
# |Vaping linked wit...|     true|       1.0|
# +--------------------+---------+----------+
