# %%
import threading

# Helper thread to avoid the Spark StreamingContext from blocking Jupyter
        
class StreamingThread(threading.Thread):
    def __init__(self, ssc):
        super().__init__()
        self.ssc = ssc
    def run(self):
        self.ssc.start()
        self.ssc.awaitTermination()
    def stop(self):
        print('----- Stopping... this may take a few seconds -----')
        self.ssc.stop(stopSparkContext=False, stopGraceFully=True)

# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://LAPTOP-DEAJH2JG:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
socketDF = spark.readStream.format("socket").option("host", "seppe.net").option("port", 7778).load()
socketDF.printSchema()
# Out:
# root
#  |-- value: string (nullable = true)

# %%
from pyspark.sql.functions import from_json, schema_of_json

# %%
def process_row(df, epoch_id):
    print(epoch_id)
    if df.count() == 0: return
    schema = schema_of_json(df.first().value)
    df_cols = df.selectExpr('CAST(value AS STRING)')\
        .select(from_json('value', schema)\
        .alias('temp'))\
        .select('temp.*')
    df_cols.show()
    # We can also save here using something such as:
    df.write.format("json").mode("append").save("data")

# %%
query = socketDF.writeStream.trigger(processingTime='5 seconds').foreachBatch(process_row).start()
# Out:
# 0
# 1
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----+-----+
# |     aid|comments|         domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|user|votes|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----+-----+
# |40185580|       0|newrepublic.com|    false|2024-04-28 02:45:54|Inside the Meltdo...|Inside the Meltdo...|The Meltdown at t...|https://newrepubl...|cwwc|    2|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----+-----+
#
# 2
# +--------+--------+--------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
# |     aid|comments|        domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|       user|votes|
# +--------+--------+--------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
# |40185633|       2|        qz.com|    false|2024-04-28 02:55:57|The S&P 500 and t...|The Nasdaq and S&...|Google surpasses ...|https://qz.com/do...|  JattMannu|    3|
# |40185636|       3|colorifyai.art|    false|2024-04-28 02:56:05|ColorifyAI - AI C...|ColorifyAI - AI C...|Show HN: Free cre...|https://colorifya...|Jasondesign|    2|
# +--------+--------+--------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
#
# 3
# +--------+--------+------------+---------+-------------------+--------------------+-------------------+--------------------+--------------------+----------+-----+
# |     aid|comments|      domain|frontpage|          posted_at|         source_text|       source_title|               title|                 url|      user|votes|
# +--------+--------+------------+---------+-------------------+--------------------+-------------------+--------------------+--------------------+----------+-----+
# |40185665|       0|localeyes.cc|    false|2024-04-28 03:03:11|Discover local ge...|Discover local gems|Share Google Maps...|https://localeyes.cc|bojanstef4|    2|
# +--------+--------+------------+---------+-------------------+--------------------+-------------------+--------------------+--------------------+----------+-----+
#
# 4
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |     aid|comments|         domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|     user|votes|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |40185667|       0|  wikipedia.org|    false|2024-04-28 03:03:14|Bonn–Oberkassel d...| Bonn–Oberkassel dog| Bonn–Oberkassel Dog|https://en.wikipe...|     Jupe|    2|
# |40185682|       0|  wikipedia.org|    false|2024-04-28 03:07:23|Global catastroph...|Global catastroph...|Global Catastroph...|https://en.wikipe...|downboots|    1|
# |40185688|       2|theguardian.com|     true|2024-04-28 03:08:00|The demise of Twi...|The demise of Twi...|The demise of Twi...|https://www.thegu...|  philk10|    8|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
#
# 5
# +--------+--------+--------------------+---------+-------------------+--------------------+------------------+--------------------+--------------------+-----------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|         source_text|      source_title|               title|                 url|       user|votes|
# +--------+--------+--------------------+---------+-------------------+--------------------+------------------+--------------------+--------------------+-----------+-----+
# |40185701|       0|      johnpweiss.com|    false|2024-04-28 03:10:36|Just a moment...\...|  Just a moment...|We Sometimes Disa...|https://johnpweis...|   herbertl|    1|
# |40185705|       0|my12parsecs.githu...|    false|2024-04-28 03:11:02|Beauty of Kamakur...|Beauty of Kamakura|  Beauty of Kamakura|https://my12parse...|my12parsecs|    1|
# +--------+--------+--------------------+---------+-------------------+--------------------+------------------+--------------------+--------------------+-----------+-----+
#
# 6
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|       user|votes|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
# |40185710|       0|       wikipedia.org|    false|2024-04-28 03:11:49|Dancing mania - W...|       Dancing mania|       Dancing Mania|https://en.wikipe...|tomcdonnell|    1|
# |40185726|       0|worldbuilding.sta...|     true|2024-04-28 03:16:54|science based - C...|Could humans alte...|Could humans alte...|https://worldbuil...|  downboots|    5|
# |40185727|       0|        theverge.com|    false|2024-04-28 03:17:17|Instagram is appa...|Instagram is appa...|Instagram is appa...|https://www.theve...|  JattMannu|    2|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-----------+-----+
#
# 7
# +--------+--------+-------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-------------+-----+
# |     aid|comments|       domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|         user|votes|
# +--------+--------+-------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-------------+-----+
# |40185752|       3|aifaceswap.io|    false|2024-04-28 03:26:42|Free AI Face Swap...|Free AI Face Swap...|Show HN: Enjoy th...|https://aifaceswa...|vtuberankings|    1|
# |40185760|       0|    quodb.com|    false|2024-04-28 03:28:46|Unveiling Hidden ...|Unveiling Hidden ...|Cinematic Treasur...|https://www.quodb...|   walterbell|    1|
# +--------+--------+-------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-------------+-----+
#
# 8
# +--------+--------+--------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----------+-----+
# |     aid|comments|        domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|      user|votes|
# +--------+--------+--------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----------+-----+
# |40185792|       0|rogerebert.com|    false|2024-04-28 03:39:13|The Fall movie re...|The Fall movie re...|The Fall movie re...|https://www.roger...|walterbell|    1|
# +--------+--------+--------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----------+-----+
#
# 9
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----------+-----+
# |     aid|comments|         domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|      user|votes|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----------+-----+
# |40185793|       0|theguardian.com|    false|2024-04-28 03:39:27|Silicon Valley’s ...|Moderating horror...|SV's business mod...|https://www.thegu...|    laurex|    1|
# |40185797|       3|   streamlit.io|     true|2024-04-28 03:40:10|       Streamlit\n\n|           Streamlit|Long-Term, Person...|https://share.str...|PHOTON1233|    3|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----------+-----+
# 10
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|          user|votes|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------+-----+
# |40185802|       0|github.com/huangy...|    false|2024-04-28 03:42:13|GitHub - huangyz0...|GitHub - huangyz0...|Show HN: Free Git...|https://github.co...|cheeseisinsane|    2|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------+-----+
#
# 11
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----------+-----+
# |     aid|comments|     domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|      user|votes|
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----------+-----+
# |40185810|       0|youtube.com|    false|2024-04-28 03:43:11|2024 White House ...|2024 White House ...|2024 White House ...|https://www.youtu...|keepamovin|    1|
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----------+-----+
#
# 12
# +--------+--------+--------------------+---------+-------------------+--------------------+------------+--------------------+--------------------+---------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|         source_text|source_title|               title|                 url|     user|votes|
# +--------+--------+--------------------+---------+-------------------+--------------------+------------+--------------------+--------------------+---------+-----+
# |40185839|       2|nationalgeographi...|     true|2024-04-28 03:50:59|El Niño\n\nDonate...|     El Niño|El Niño is a clim...|https://education...|JattMannu|    6|
# +--------+--------+--------------------+---------+-------------------+--------------------+------------+--------------------+--------------------+---------+-----+
#
# 13
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
# |     aid|comments|     domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|  user|votes|
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
# |40185852|       0|latimes.com|    false|2024-04-28 03:53:39|Nearly 3 million ...|Millions could lo...|Millions could lo...|https://www.latim...|laurex|    1|
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
#
# 14
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|   user|votes|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-------+-----+
# |40185875|       0|computingwithinli...|    false|2024-04-28 03:59:58|LIMITS 2024 -- Wo...|LIMITS 2024 -- Wo...|Computing Within ...|https://computing...|  pabs3|    1|
# |40185877|       0|     dailymail.co.uk|    false|2024-04-28 04:01:23|Britain will need...|Britain 'will nee...|Britain will need...|https://www.daily...|tomerbd|    1|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-------+-----+
#
# 15
# +--------+--------+--------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
# |     aid|comments|        domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|  user|votes|
# +--------+--------+--------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
# |40185881|       0|apps.apple.com|    false|2024-04-28 04:02:13|AI on Device - Lo...|AI on Device - Lo...|Another local LLM...|https://apps.appl...|iMax00|    1|
# +--------+--------+--------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
#
# 16
# +--------+--------+----------------+---------+-------------------+--------------------+-----------------+-----------------+--------------------+----------+-----+
# |     aid|comments|          domain|frontpage|          posted_at|         source_text|     source_title|            title|                 url|      user|votes|
# +--------+--------+----------------+---------+-------------------+--------------------+-----------------+-----------------+--------------------+----------+-----+
# |40185883|       9|quantumai.google|     true|2024-04-28 04:02:21|Google Quantum AI...|Google Quantum AI|Google Quantum AI|https://quantumai...|segasaturn|   19|
# +--------+--------+----------------+---------+-------------------+--------------------+-----------------+-----------------+--------------------+----------+-----+
#
# 17
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------------+-----+
# |     aid|comments|     domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|        user|votes|
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------------+-----+
# |40185890|       6|science.org|     true|2024-04-28 04:03:43|Just a moment...\...|    Just a moment...|Can science find ...|https://www.scien...|    chapulin|   11|
# |40185903|       0|  bbc.co.uk|     true|2024-04-28 04:07:24|American Airlines...|American Airlines...|Airline keeps mis...|https://www.bbc.c...|user20180120|    5|
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------------+-----+
#
# 18
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|    user|votes|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------+-----+
# |40185951|       0|     chat.openai.com|    false|2024-04-28 04:18:20|ChatGPT - TweetSt...|ChatGPT - TweetSt...|I Made This AI Tw...|https://chat.open...|  siadam|    1|
# |40185970|       2|twitter.com/ilyas...|     true|2024-04-28 04:23:40|X\n\nDon’t miss w...|                   X|44% Unicorn Start...|https://twitter.c...|ZuckMusk|    5|
# |40185986|       0|         youtube.com|     true|2024-04-28 04:26:18|nation state back...|nation state back...|Nation state back...|https://www.youtu...|    chii|    6|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------+-----+
#
#
------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-------+-----+
#
# 50
# +--------+--------+-----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |     aid|comments|           domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|     user|votes|
# +--------+--------+-----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |40186819|       0|anniecherkaev.com|    false|2024-04-28 07:47:09|principles for ke...|principles for ke...|Principles for Ke...|https://anniecher...|  skilled|    1|
# |40186857|       0|      9to5mac.com|    false|2024-04-28 07:56:43|100,000 iPhones s...|100,000 iPhones s...|iPhones stolen in...|https://9to5mac.c...|mindracer|    1|
# +--------+--------+-----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
#
# 51
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-------+-----+
# |     aid|comments|         domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|   user|votes|
# ...
# |40186870|       0|       okta.com|    false|2024-04-28 07:59:28|How to Block Resi...|How to Block Resi...|Okta warns of cre...|https://sec.okta....|skilled|    1|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-------+-----+
#
# 52
# +--------+--------+----------------+---------+-------------------+--------------------+------------+--------------------+--------------------+-------+-----+
# |     aid|comments|          domain|frontpage|          posted_at|         source_text|source_title|               title|                 url|   user|votes|
# +--------+--------+----------------+---------+-------------------+--------------------+------------+--------------------+--------------------+-------+-----+
# |40186873|       0|thenational.scot|    false|2024-04-28 08:00:14|Chaotix\n\nPresen...|     Chaotix|Humza Yousaf pled...|https://www.thena...|yassinn|    1|
# +--------+--------+----------------+---------+-------------------+--------------------+------------+--------------------+--------------------+-------+-----+
#
# 53
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------+-----+
# |     aid|comments|         domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|    user|votes|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------+-----+
# |40186887|       0|    chaotix.app|    false|2024-04-28 08:01:22|Chaotix\n\nPresen...|             Chaotix|Show HN: We launc...|https://chaotix.app/| AnkurCW|    2|
# |40186919|       0|     dubroy.com|    false|2024-04-28 08:06:46|Three ways of han...|Three ways of han...|Three ways of han...|https://dubroy.co...|stcucufa|    1|
# |40186938|       0|xinyuan1666.com|    false|2024-04-28 08:11:01|NewsNuggets AI\n\...|      NewsNuggets AI|Effortless Summar...|https://news-nugg...|lickfeng|    1|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------+-----+
#
# 54
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |     aid|comments|     domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|     user|votes|
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |40186953|       0|youtube.com|    false|2024-04-28 08:15:38|Daniel Dennett - ...|Daniel Dennett - ...|Daniel Dennett – ...|https://www.youtu...|networked|    1|
# |40186960|       6|  eaton.com|     true|2024-04-28 08:17:47|www.eaton.com\n\n...|       www.eaton.com|Is it okay to dai...|https://www.eaton...|    nuker|   11|
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
#
# 55
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |     aid|comments|          domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|     user|votes|
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |40187032|       0|         cmu.edu|    false|2024-04-28 08:44:05|Heartbeat Schedul...|Heartbeat Scheduling|Heartbeat Schedul...|https://www.andre...|g0xA52A2A|    1|
# |40187034|       0|steampowered.com|    false|2024-04-28 08:44:18|Save 25% on Manor...|Save 25% on Manor...|Manor Lords is a ...|https://store.ste...|   doener|    1|
# +--------+--------+----------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# 56
# +--------+--------+--------------------+---------+-------------------+--------------------+----------------+--------------------+--------------------+---------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|         source_text|    source_title|               title|                 url|     user|votes|
# +--------+--------+--------------------+---------+-------------------+--------------------+----------------+--------------------+--------------------+---------+-----+
# |40187044|       0|medium.com/lb.wri...|    false|2024-04-28 08:46:28|Just a moment...\...|Just a moment...|Vault Dwellers an...|https://medium.co...|  leobear|    1|
# |40187056|       0|          xtopics.co|    false|2024-04-28 08:48:34|Grow on X with le...|            NULL|Show HN: XTopics ...|  https://xtopics.co|tropianhs|    1|
# +--------+--------+--------------------+---------+-------------------+--------------------+----------------+--------------------+--------------------+---------+-----+
#
# 57
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----+-----+
# |     aid|comments|     domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|user|votes|
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----+-----+
# |40187058|       0|youtube.com|    false|2024-04-28 08:49:25|The Catch To Appl...|The Catch To Appl...|The Catch to Appl...|https://www.youtu...|chii|    1|
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+----+-----+
#
# 58
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
# |     aid|comments|         domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|  user|votes|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
# |40187063|       0|theatlantic.com|    false|2024-04-28 08:50:17|Why China Can’t G...|How the Humble Do...|How the Humble Do...|https://www.theat...|ccpbot|    1|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
#
# 59
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------------+-----+
# |     aid|comments|         domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|        user|votes|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------------+-----+
# |40187072|       0|    krasjet.com|    false|2024-04-28 08:51:18|pdf.tocgen\n\n# p...|          pdf.tocgen|          Pdf.tocgen|https://krasjet.c...|    nbernard|    1|
# |40187073|       0|spectator.co.uk|    false|2024-04-28 08:51:22|How America plund...|How America plund...|America plunders ...|https://www.spect...|jayceedenton|    1|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------------+-----+
#
# 60
# +--------+--------+------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-------+-----+
# |     aid|comments|      domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|   user|votes|
# +--------+--------+------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-------+-----+
# |40187088|       0|hackaday.com|    false|2024-04-28 08:54:33|Train A GPT-2 LLM...|Train A GPT-2 LLM...|Train a GPT-2 LLM...|https://hackaday....|mdp2021|    1|
# +--------+--------+------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+-------+-----+
#
# 61
# +--------+--------+------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
# |     aid|comments|      domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|  user|votes|
# +--------+--------+------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
# |40187102|       0|hackaday.com|    false|2024-04-28 08:56:44|Pi Pico Gets A ZX...|Pi Pico Gets A ZX...|Pi Pico Gets a ZX...|https://hackaday....|rcarmo|    1|
# +--------+--------+------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
#
# 62
# +--------+--------+--------------------+---------+-------------------+--------------------+------------+--------------------+--------------------+-------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|         source_text|source_title|               title|                 url|   user|votes|
# +--------+--------+--------------------+---------+-------------------+--------------------+------------+--------------------+--------------------+-------+-----+
# |40187105|       0|twitter.com/juans...|    false|2024-04-28 08:57:21|X\n\nDon’t miss w...|           X|Voice to PDF – Co...|https://twitter.c...|jstoppa|    1|
# +--------+--------+--------------------+---------+-------------------+--------------------+------------+--------------------+--------------------+-------+-----+
#
# 63
# +--------+--------+------------------+---------+-------------------+--------------------+-----------------+-----------------+--------------------+--------+-----+
# |     aid|comments|            domain|frontpage|          posted_at|         source_text|     source_title|            title|                 url|    user|votes|
# +--------+--------+------------------+---------+-------------------+--------------------+-----------------+-----------------+--------------------+--------+-----+
# |40187117|       0|alearningaday.blog|    false|2024-04-28 09:00:03|Trade-off honesty...|Trade-off honesty|Trade-Off Honesty|https://alearning...|herbertl|    1|
# +--------+--------+------------------+---------+-------------------+--------------------+-----------------+-----------------+--------------------+--------+-----+
#
# 64
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |     aid|comments|     domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|     user|votes|
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |40187119|       0|glarity.app|    false|2024-04-28 09:00:25|AI Search Engine ...|AI Search Engine ...|What innovative i...|https://blog.glar...|james_chu|    1|
# +--------+--------+-----------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
#
# 65
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------+-----+
# |     aid|comments|              domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|    user|votes|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------+-----+
# |40187129|       0|directionsonmicro...|     true|2024-04-28 09:02:18|Microsoft must st...|Microsoft must st...|Microsoft must st...|https://www.direc...|herbertl|    8|
# +--------+--------+--------------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+--------+-----+
# 66
# +--------+--------+----------+---------+-------------------+--------------------+--------------------+--------------------+-------------------+------+-----+
# |     aid|comments|    domain|frontpage|          posted_at|         source_text|        source_title|               title|                url|  user|votes|
# +--------+--------+----------+---------+-------------------+--------------------+--------------------+--------------------+-------------------+------+-----+
# |40187139|       0|masto.host|    false|2024-04-28 09:04:33|Masto.host - Full...|Masto.host - Full...|Managed Mastodon ...|https://masto.host/|doener|    1|
# +--------+--------+----------+---------+-------------------+--------------------+--------------------+--------------------+-------------------+------+-----+
#
# 67
# +--------+--------+------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
# |     aid|comments|      domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|  user|votes|
# +--------+--------+------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
# |40187145|       0|spacebear.ee|    false|2024-04-28 09:05:40|Spacebear Federat...|Spacebear Federation|Spacebear Federat...|https://federatio...|doener|    1|
# +--------+--------+------------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+------+-----+
#
# 68
# +--------+--------+---------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |     aid|comments|   domain|frontpage|          posted_at|         source_text|        source_title|               title|                 url|     user|votes|
# +--------+--------+---------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
# |40187146|       0|arxiv.org|    false|2024-04-28 09:05:43|[2404.16222] Step...|Step Differences ...|Step Differences ...|https://arxiv.org...|zerojames|    1|
# +--------+--------+---------+---------+-------------------+--------------------+--------------------+--------------------+--------------------+---------+-----+
#
# 69
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+-------+--------------------+------+-----+
# |     aid|comments|         domain|frontpage|          posted_at|         source_text|        source_title|  title|                 url|  user|votes|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+-------+--------------------+------+-----+
# |40187153|       0|greenash.net.au|    false|2024-04-28 09:07:00|On FastAPI - Gree...|On FastAPI - Gree...|FastAPI|https://greenash....|rcarmo|    1|
# +--------+--------+---------------+---------+-------------------+--------------------+--------------------+-------+--------------------+------+-----+

# %%
query.stop()
